# %%
import os
os.environ["OMP_NUM_THREADS"] = "6"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
from collections import Counter

#für Hierarchisches Clustering
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

import glob

# %%
#angepasst auf finale datei
seq_regions = ['SEQ_H1', 'SEQ_H2', 'SEQ_L1', 'SEQ_L2', 'SEQ_L3']
cf_regions = ['CF_H1', 'CF_H2', 'CF_L1', 'CF_L2', 'CF_L3']
df = (
    pd.read_csv("data/ab_ag_scalop.tsv", sep="\t")
    .dropna(subset=seq_regions)
    .dropna(subset=cf_regions)
    .drop_duplicates(subset=seq_regions) 
)


antigen_counts = df["antigen_name"].value_counts() # Tabelle aus antigen_names und ihren Häufigkeiten in der Spalte antigen_name
df = df[df["antigen_name"].isin(antigen_counts[antigen_counts >= 5].index)] # Behält nur Zeilen, deren antigen_name mindestens 5-mal vorkommt

# %%
#für jede Region und jede Sequenzlänge separate Subgruppen erstellen und diese dann clustern

# Agglomeratives Clustering mit Ward-Methode
# Euklidische Distanz wird als Maß für die Distanz zwischen den Datenpunkten genutzt

# Ziel: Ähnliche Sequenzen sollen in Clustern zusammengefasst werden
# Die hierarchische Clusterstruktur wird als Dendrogramm dargestellt

# Ausgabe-Ordner erstellen
os.makedirs("data/cdr_cluster_HC_length_tsvs", exist_ok=True)


# Liste der 20 Standard-Aminosäuren
AA_LIST = list("ACDEFGHIKLMNPQRSTVWY")

def aa_freq_vector(seq: str) -> np.ndarray: #aa_freq_vector name der Funktion, nimmt eine sequenz, die string sein soll, rückgabe ist np.ndarray (Vektor)
    counts = np.array([seq.count(aa) for aa in AA_LIST], dtype=float) # Häufigkeit jeder AS in der sequenz für jede AS der liste AA_LIST, als numpy array (also mit Gleitkommazahlen)
    return counts / len(seq) #direkte Normierung (also realtiver anteil jeder AS in der sequenz)

#diese Häufigkeitsvektoren der AS in den Sequnenzen dienen als Input für das hierarchische Clustering

# Hauptschleife: je Region und je Sequenzlänge separate Subgruppen

for region in seq_regions:
    # Ermittle alle eindeutigen Sequenzlängen in dieser Region
    lengths = sorted(df[region].str.len().dropna().unique()) #so weiß man welche sequenzlängen bei einer region vorkommen

    for L in lengths: #es werden nicht nur für jede region dendrogramme ertsellt sondern auch für jede Sequenzlänge in dieser Region
        # Subset für die aktuelle Länge
        sub_df = df[df[region].str.len() == L][[region, "pdb", "Hchain", "Lchain", "antigen_name"]].reset_index(drop=True) #drop=True sorgt dafür, dass der alte Index komplett verworfen wird und nicht als zusätzliche Spalte im DataFrame auftaucht
        #in sub df werden alle sequnezen der aktuellen region und länge gespeichert, sowie die zugehörigen PDBs, Hchains, Lchains und antigen_names
        seqs = sub_df[region].tolist() #extrahiere die Sequenzen für die aktuelle Region und Länge als Liste
        X = np.vstack([aa_freq_vector(s) for s in seqs]) #berechnet für jede Sequenz den normierten Aminosäurehäufigkeitsvektor und fasst alle zu einer Matrix zusammen

        # Linkage berechnen (Ward-Methode, euklidische Distanz)
        Z = linkage(X, method="ward", metric="euclidean") #erstellt aus feature matrix X ein hierarchisches Clustering, das Ergebnis ist eine Linkage-Matrix Z
        #ward minimiert varianz innerhalb der cluster bei jedem merge denn beginnt mit jedem einzelnen Punkt als Cluster und fügt diese dann schrittweise zusammen (immer 2 werden gemerged)
        #gesamtvarianz ist die Summe der quadrierten Abstände der Punkte zu ihrem Zentroid
        #euklidische distanz = wurzel aus der Summe der quadrierten Differenzen der Koordinaten (kann gut von ward methode genutzt werden)
        
        threshold_ratio = 0.5  # 50 % der maximalen Mergehöhe, also vom letzten merge
        max_d = Z[:, 2].max() #3. spalte der Linkage-Matrix Z enthält die Distanzen der merges
        threshold = threshold_ratio * max_d # so wird der Schwellenwert relativ zur struktur der daten gewählt (wenn datenpunkte nah beieinander liegen, ist der Schwellenwert kleiner, wenn sie weiter auseinander liegen, ist der Schwellenwert größer)

        # Dendrogrammdaten ohne Plot für Farbzuordnung
        ddata = dendrogram(
            Z,
            labels=[str(i) for i in range(len(seqs))],
            color_threshold=threshold, #steuert ab welcher merge distanz die zweige des baums unterschiedlich gefärbt werden
            no_plot=True #unterdrückt die grafik, liefert aber alle Daten für die weitere Verarbeitung
        )

        # verbindet blatt indizes mit den Farben
        leaves = ddata['leaves'] # Reihenfolge der Blatt-Indizes
        leaf_colors = ddata['leaves_color_list'] # RGB-Farben pro Blatt, gemäß threshold
        leaf_color_map = dict(zip(leaves, leaf_colors))
                    #zip leaves verbindet blatt_indizes mit jeweiliger Farbe, ordnet also jedem blatt/Sequenz eine Farbe zu 
                    #leaf: baut ein dict, indem der Blatt_index(leaves) und das entsprechende RGB-Farb-Tuple (col) ist
                    #mit der map kann man dann erkennen, welche Sequenz (Blatt) welche Farbe hat

        #Sicherstellen dass jede frabe nur einmal vorkommt und in der Reihenfolge der Blätter
        unique_colors = [] 
        for col in leaves_colors: #leaves_colors ist eine Liste der Farben, die den Blättern zugeordnet sind
            if col not in unique_colors:
                unique_colors.append(col) #falls farbe eines blattes noch nicht in unique colors wird sie hinzugefügt, in gleicher Reihenfolge

        #Weise jeder Farbe eine Cluster-Nummer zu
        color_cluster_map = {col: idx+1 for idx, col in enumerate(unique_colors)} #enumerate gibt jedem Eintrag in unique_colors eine Nummer, beginnend bei 1 (durch idx+1)

        # TSV-Einträge sammeln
        entries = []
        for col in unique_colors:
           
            cid = color_cluster_map[col] 
            pdbs_in_cluster = [leaf for leaf, c in leaf_color_map.items() if c == col] #sucht alle Blatt-Indizes (Sequenzen/PDBs) in der map mit leafs und farben, deren Farbe col entspricht also zu diesem Cluster gehören
            
            for leaf_idx in pdbs_in_cluster: #Index im Dataframe (entspricht der Reihenfolge im Dendrogramm)
                pdb_id = df.iloc[leaf_idx]["pdb"]  # Hole echte PDB-ID aus Original-DataFrame
                Hchain = df.iloc[leaf_idx]["Hchain"]  # Hole Hchain aus Original-DataFrame
                Lchain = df.iloc[leaf_idx]["Lchain"]  # Hole Lchain aus Original-DataFrame
                entries.append((pdb_id, Hchain, Lchain, cdr, cluster_id))


        # Jetzt Datei für diese CDR schreiben
        filename = f"data/cdr_cluster_tsvs/clusters_{cdr}.tsv"
        with open(filename, "w", newline="") as f: #öffnet datei mit filename im Schreibmodus(w), newline""" verhindert zusätzliche Leerzeilen, f als referenz auf die Datei
            writer = csv.writer(f, delimiter="\t") #Erzeugt ein CSV-Writer-Objekt, das in f schreibt
            writer.writerow(["pdb", "Hchain", "Lchain", "CDR", "Cluster_Label"]) #kopfzeile mit spaltennamen
            writer.writerows(entries) #schreibt alles aus tsv entries da rein, liste enthält Tupel mit pdb_id, cdr und cluster_id


        # Plot Dendrogramm 
        dendrogram(
            Z,
            labels=[str(i) for i in range(len(seqs))],
            color_threshold=threshold,
            leaf_rotation=0,
            leaf_font_size=6
        )
        plt.title(f"Dendrogramm: {region} (Len={L}")
        plt.xlabel("Distance")
        plt.tight_layout()
        plt.show()

        #Auswertung der Teilbäume
        print(f"\n{region}, Länge {L} → {len(unique_colors)} Subgruppen:")
        for col in unique_colors:
            cid = color_cluster_map[col] #cluster id für die aktuelle Farbe
            leaves_in_cluster = [leaf for leaf, c in leaf_color_map.items() if c == col] #filtert die Blätter, die zu diesem Cluster gehören
            antigens = sub_df.loc[leaves_in_cluster, 'antigen_name'] #hole für die Blätter die Antigen-Namen aus dem Sub-DataFrame
            pdbs = sub_df.loc[leaves_in_cluster, 'pdb']
            seq_list = sub_df.loc[leaves_in_cluster, region]

            counts = Counter(antigens)
            print(f"  Cluster {cid}:")
            print("    Antigen-Verteilung:")
            for ag, cnt in counts.most_common():
                print(f"      {ag}: {cnt}x")
            print("    PDBs:")
            for p in pdbs:
                print(f"      {p}")
            print("    Sequenzen:")
            for s in seq_list:
                print(f"      {s}")
        print("\n" + "-"*50 + "\n")
# Out:
# TSV geschrieben: data/cdr_cluster_HC_length_tsvs/clusters_SEQ_H1_len7.tsv
# SEQ_H1, Länge 7 → 5 Subgruppen:
#   Cluster 1:
#     Antigen-Verteilung:
#       spike glycoprotein: 36x
#       spike protein s1: 21x
#       leukocyte surface antigen cd47: 5x
#       envelope glycoprotein gp160: 5x
#       fusion glycoprotein f0: 5x
#       neuraminidase: 5x
#       gametocyte surface protein p230: 4x
#       ch848.10.17 gp120: 4x
#       envelope glycoprotein b: 4x
#       clade a/e 93th057 hiv-1 gp120 core: 4x
#       envelope glycoprotein e2: 3x
#       hemagglutinin ha1 chain: 3x
#       hemagglutinin: 3x
#       sars-cov-2 spike glycoprotein: 2x
#       programmed cell death protein 1: 2x
#       25 kda ookinete surface antigen: 2x
#       interleukin-1 beta: 2x
#       envelope protein: 2x
#       envelope glycoprotein gp120: 2x
#       surface glycoprotein: 2x
#       gametocyte surface protein p45/48: 2x
#       spike glycoprotein,fibritin: 2x
# ...

# %%
#Hierarchisches Clustering abgeschlossen, jetzt Dateien zusammenführen
#wird gebraucht für v-measure 

# Verzeichnis mit deinen TSV-Dateien
path = "data/cdr_cluster_HC_length_tsvs"
all_files = glob.glob(os.path.join(path, "*.tsv")) #dateien wo path passt und format tsv haben werden gespeichert 
# Wir gehen die einzelnen CDRs durch
cdrs = ["H1", "H2", "L1", "L2", "L3"]

for cdr in cdrs:
    # Dateien für die aktuelle CDR sammeln
    pattern = os.path.join(path, f"*{cdr}*.tsv") #also alle dateien die in cdr_cluster_HC_length_tsvs liegen und z.b. H1 enthalten => kombiniertes Suchmuster
    all_files = glob.glob(pattern) #glob.glob(pattern) durchsucht das Verzeichnis nach Dateien, die dem Muster entsprechen, die werden gesammelt

    print(f"\nFür CDR {cdr} wurden gefunden: {len(all_files)} Dateien")
    
    dfs = []
    for file in all_files:
        print(f" - {file}")
        df = pd.read_csv(file, sep="\t")
        # Cluster-Spalte bauen und diese befüllen mit Clusterbezeichnung für jeden Eintrag/Sequenz
        df["cluster"] = df["CDR"].astype(str) + "_" + df["Length"].astype(str) + "_" + df["Cluster_Label"].astype(str)
        #relevante Spalten behalten
        df = df[["pdb", "Hchain", "Lchain", "cluster"]]
        dfs.append(df)

    if dfs:
        merged_df = pd.concat(dfs, ignore_index=True) #alle gesammelten dfs zusammenführen
        # Speichern
        output_file = f"data/merged_clusters_{cdr}.csv" # Dateiname für die zusammengeführten Daten
        merged_df.to_csv(output_file, index=False) #df wird als CSV-Datei gespeichert, ohne den Index
        print(f"=> Datei gespeichert: {output_file} mit {len(merged_df)} Zeilen")
    else:
        print(f"=> Keine Dateien für CDR {cdr} gefunden.")
# Out:
# Für CDR H1 wurden gefunden: 3 Dateien
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_H1_len7.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_H1_len8.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_H1_len9.tsv
# => Datei gespeichert: data/merged_clusters_H1.csv mit 712 Zeilen
#
# Für CDR H2 wurden gefunden: 3 Dateien
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_H2_len5.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_H2_len6.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_H2_len8.tsv
# => Datei gespeichert: data/merged_clusters_H2.csv mit 712 Zeilen
#
# Für CDR L1 wurden gefunden: 8 Dateien
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_L1_len10.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_L1_len11.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_L1_len12.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_L1_len13.tsv
#  - data/cdr_cluster_HC_length_tsvs\clusters_SEQ_L1_len14.tsv
# ...

# %%
#hierarchical clustering => visualisierung in dendrogramm
#für jede Region und jede Sequenzlänge separate Subgruppen erstellen und diese dann clustern
#zusätzlich anzahl der cluster pre decided based on anzahl der canonical forms der jeweiligen Region und Länge

df = (
    pd.read_csv("data/ab_ag_scalop.tsv", sep="\t")
    .dropna(subset=seq_regions)
    .dropna(subset=cf_regions)
    .drop_duplicates(subset=seq_regions) 
)


antigen_counts = df["antigen_name"].value_counts() # Tabelle aus antigen_names und ihren Häufigkeiten in der Spalte antigen_name
df = df[df["antigen_name"].isin(antigen_counts[antigen_counts >= 5].index)] # Behält nur Zeilen, deren antigen_name mindestens 5-mal vorkommt

# Ausgabe-Ordner erstellen
os.makedirs("data/cdr_cluster_pre_decided_HC_length_tsvs", exist_ok=True)
# Anzahl Cluster pro (Region, Länge) aus SabDab
cluster_counts = {
    ("SEQ_H1", 7): 4, ("SEQ_H1", 8): 2, ("SEQ_H1", 9): 1,
    ("SEQ_H2", 5): 1, ("SEQ_H2", 6): 5, ("SEQ_H2", 8): 1,
    ("SEQ_L1",10): 1, ("SEQ_L1",11): 2, ("SEQ_L1",12): 2,
    ("SEQ_L1",13): 3, ("SEQ_L1",14): 3, ("SEQ_L1",15): 1,
    ("SEQ_L1",16): 1, ("SEQ_L1",17): 1,
    ("SEQ_L2", 7): 1,
    ("SEQ_L3", 5): 1, ("SEQ_L3", 8): 1, ("SEQ_L3", 9): 1,
    ("SEQ_L3",10): 2, ("SEQ_L3",11): 1,
}
for region in seq_regions:
    lengths = sorted(df[region].str.len().dropna().unique())
    for L in lengths:
# Parameter für Dendrogramm-Cut
        levels_down = cluster_counts.get((region, L), 1)-1  # Anzahl der Ebenen für den Cut; etwa 2 = 3 Teilbäume
        print(levels_down)
# Liste der 20 Standard-Aminosäuren
        AA_LIST = list("ACDEFGHIKLMNPQRSTVWY")

        def aa_freq_vector(seq: str) -> np.ndarray:
            """Berechnet den normierten Häufigkeitsvektor der 20 Standard-Aminosäuren."""
            counts = np.array([seq.count(aa) for aa in AA_LIST], dtype=float)
            return counts / len(seq)


        sub_df = df[df[region].str.len() == L][[region, "pdb", "Hchain", "Lchain", "antigen_name"]].reset_index(drop=True)
        seqs = sub_df[region].tolist()
        X = np.vstack([aa_freq_vector(s) for s in seqs]) #für jede Sequenz den normierten Aminosäurehäufigkeitsvektor berechnen und alle zu einer Matrix zusammenfassen

        # Hierarchisches Clustering
        Z = linkage(X, method="ward", metric="euclidean")
        threshold = Z[-levels_down, 2] if levels_down <= Z.shape[0] else 0.0

        # Dendrogrammdaten ohne Plot für Farbzuordnung
        ddata = dendrogram(
            Z,
            labels=[str(i) for i in range(len(seqs))],
            color_threshold=threshold,
            no_plot=True
        )

        # Blatt-Farben extrahieren
        leaves = ddata['leaves']
        leaf_colors = ddata['leaves_color_list']
        leaf_color_map = dict(zip(leaves, leaf_colors))

        #Sicherstellen dass jede frabe nur einmal vorkommt und in der Reihenfolge der Blätter
        unique_colors = [] 
        for col in leaves_colors: #leaves_colors ist eine Liste der Farben, die den Blättern zugeordnet sind
            if col not in unique_colors:
                unique_colors.append(col) #falls farbe eines blattes noch nicht in unique colors wird sie hinzugefügt, in gleicher Reihenfolge

        # Weise jeder Farbe eine Cluster-Nummer zu
        color_cluster_map = {col: idx+1 for idx, col in enumerate(unique_colors)} #enumerate gibt jedem Eintrag in unique_colors eine Nummer, beginnend bei 1 (durch idx+1)

        # TSV-Einträge sammeln
        entries = []
        for col in unique_colors:
            cid = color_cluster_map[col]
            leaves_in_cluster = [leaf for leaf, c in leaf_color_map.items() if c == col] #sucht alle Blatt-Indizes (Sequenzen/PDBs) in der map mit leafs und farben, deren Farbe col entspricht also zu diesem Cluster gehören
            for leaf_idx in leaves_in_cluster: #index im Dataframe (entspricht der Reihenfolge im Dendrogramm)
                pdb_id = sub_df.iloc[leaf_idx]['pdb'] # Hole echte PDB-ID aus Original-DataFrame
                Hchain = sub_df.iloc[leaf_idx]['Hchain']
                Lchain = sub_df.iloc[leaf_idx]['Lchain']
                entries.append((pdb_id, Hchain, Lchain, region, L, cid, antigen_name))

        # Schreibe TSV für Region und Länge
        tsv_file = f"data/cdr_cluster_pre_decided_HC_length_tsvs/clusters_{region}_len{L}.tsv"
        with open(tsv_file, 'w', newline='') as f:
            writer = csv.writer(f, delimiter='\t')
            writer.writerow(["PDB_ID", "Hchain", "Lchain", "CDR", "Length", "Cluster_Label", "antigen_name"])
            writer.writerows(entries)
        print(f"TSV geschrieben: {tsv_file}")

        # Plot Dendrogramm
        dendrogram(
            Z,
            labels=[str(i) for i in range(len(seqs))],
            color_threshold=threshold,
            leaf_rotation=0,
            leaf_font_size=6
        )
        plt.title(f"Dendrogramm: {region} (Len={L}, cut={levels_down} levels)")
        plt.xlabel("Distance")
        plt.tight_layout()
        plt.show()

        # Konsolenausgabe der Cluster-Inhalte
        print(f"\n{region}, Länge {L} → {len(unique_colors)} Subgruppen:")
        for col in unique_colors:
            cid = color_cluster_map[col]
            leaves_in_cluster = [leaf for leaf, c in leaf_color_map.items() if c == col]
            antigens = sub_df.loc[leaves_in_cluster, 'antigen_name']
            pdbs = sub_df.loc[leaves_in_cluster, 'pdb']
            seq_list = sub_df.loc[leaves_in_cluster, region]

            counts = Counter(antigens)
            print(f"  Cluster {cid}:")
            print("    Antigen-Verteilung:")
            for ag, cnt in counts.most_common():
                print(f"      {ag}: {cnt}x")
            print("    PDB_IDs:")
            for p in pdbs:
                print(f"      {p}")
            print("    Sequenzen:")
            for s in seq_list:
                print(f"      {s}")
        print("\n" + "-"*50 + "\n")
# Out:
# 3
# TSV geschrieben: data/cdr_cluster_pre_decided_HC_length_tsvs/clusters_SEQ_H1_len7.tsv
# SEQ_H1, Länge 7 → 4 Subgruppen:
#   Cluster 1:
#     Antigen-Verteilung:
#       spike glycoprotein: 36x
#       spike protein s1: 21x
#       leukocyte surface antigen cd47: 5x
#       envelope glycoprotein gp160: 5x
#       fusion glycoprotein f0: 5x
#       neuraminidase: 5x
#       gametocyte surface protein p230: 4x
#       ch848.10.17 gp120: 4x
#       envelope glycoprotein b: 4x
#       clade a/e 93th057 hiv-1 gp120 core: 4x
#       envelope glycoprotein e2: 3x
#       hemagglutinin ha1 chain: 3x
#       hemagglutinin: 3x
#       sars-cov-2 spike glycoprotein: 2x
#       programmed cell death protein 1: 2x
#       25 kda ookinete surface antigen: 2x
#       interleukin-1 beta: 2x
#       envelope protein: 2x
#       envelope glycoprotein gp120: 2x
#       surface glycoprotein: 2x
#       gametocyte surface protein p45/48: 2x
#       spike glycoprotein,fibritin: 2x
# ...

# %%
#hierarchical clustering abgeschlossen, jetzt dateien zusammenführen
# wird gebraucht für v-measure

# Verzeichnis mit deinen TSV-Dateien
path = "data/cdr_cluster_pre_decided_HC_length_tsvs"
all_files = glob.glob(os.path.join(path, "*.tsv")) #glob.glob folgt path und sucht dort alle Dateien im Verzeichnis, die auf .tsv enden 
# Wir gehen die einzelnen CDRs durch
cdrs = ["H1", "H2", "L1", "L2", "L3"]

for cdr in cdrs:
    # Dateien für die aktuelle CDR sammeln
    pattern = os.path.join(path, f"*{cdr}*.tsv") #verbindet ordnerpfad mit Dateiname => Suchmuster
    all_files = glob.glob(pattern) #alle dateien, die dem Muster entsprechen, werden gesammelt

    print(f"\nFür CDR {cdr} wurden gefunden: {len(all_files)} Dateien")
    
    dfs = []
    for file in all_files:
        print(f" - {file}")
        df = pd.read_csv(file, sep="\t")
        # Cluster-Spalte bauen
        df["cluster"] = df["CDR"].astype(str) + "_" + df["Length"].astype(str) + "_" + df["Cluster_Label"].astype(str)
        # Nur relavnte Spalten behalten
        df = df[["PDB_ID", "Hchain", "Lchain", "cluster"]]
        dfs.append(df)

    if dfs: #also wenn daten vorhanden waren zusammenführen und speichern
        merged_df = pd.concat(dfs, ignore_index=True)
        # Speichern
        output_file = f"data/merged_clusters_pre_decided_{cdr}.csv"
        merged_df.to_csv(output_file, index=False)
        print(f"=> Datei gespeichert: {output_file} mit {len(merged_df)} Zeilen")
    else:
        print(f"=> Keine Dateien für CDR {cdr} gefunden.")
# Out:
# Für CDR H1 wurden gefunden: 3 Dateien
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_H1_len7.tsv
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_H1_len8.tsv
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_H1_len9.tsv
# => Datei gespeichert: data/merged_clusters_pre_decided_H1.csv mit 712 Zeilen
#
# Für CDR H2 wurden gefunden: 3 Dateien
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_H2_len5.tsv
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_H2_len6.tsv
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_H2_len8.tsv
# => Datei gespeichert: data/merged_clusters_pre_decided_H2.csv mit 712 Zeilen
#
# Für CDR L1 wurden gefunden: 8 Dateien
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_L1_len10.tsv
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_L1_len11.tsv
#  - data/cdr_cluster_pre_decided_HC_length_tsvs\clusters_SEQ_L1_len12.tsv
# ...
